# %% [markdown]
# # Assessment

# %% [markdown]
# <p style='text-align: justify;'>
# Congratulations on finishing the HPC simulations course!! Hopefully you learned some valuable skills along the way and had fun doing it. Now it's time to put these skills to the test. In this evaluation, we have the following problem: Create a neural network to predict atmospheric wind speed. You must create and train a model using one of the tools studied and evaluate its performance. Let's get started!
# </p>

# %% [markdown]
# ## Problem: Predict atmospheric wind speed

# %% [markdown]
# <p style='text-align: justify;'>
# Predicting atmospheric wind speed is of great importance in various applications, such as weather forecasting, aviation, wind energy park deployment, among others. An accurate understanding of wind speed and direction is essential for making informed decisions in many sectors.
# </p>
# <p style='text-align: justify;'>
# In this challenge, your goal is to develop a machine learning model capable of predicting wind speed one hour ahead. To accomplish this, you will use one of the tools studied in the course and leverage the knowledge you have acquired to create and train a precise neural network model using appropriate computational resources. After training the model, you will also need to assess its forecasting ability and determine its effectiveness.
# </p>
#
# <p style="text-align: center;">
#  <img src="../images/figure01_meteorological_station.jpg" style="width: 700px;">
# </p>

# %% [markdown]
# ### Wind dataset
#
# We will use the [Wind dataset](data/wind-dataset/wind-dataset.csv) of a city where we will have various meteorological information available in which we will obtain information related to wind measurement so that we can develop our algorithm. Let's look at a sample below.

# %% [markdown]
# |   id |   year |   day |   min |   dir_avg |   tp_sfc |   humid |   press |   ws_10m |   wd_10m |
# |-----:|-------:|------:|------:|----------:|---------:|--------:|--------:|---------:|---------:|
# |    1 |   2019 |    91 |     0 |    -0.417 |    24.62 |   89.8  | 1010.86 |    1.273 |     64.5 |
# |    2 |   2019 |    91 |     1 |    -0.377 |    24.69 |   89.7  | 1010.83 |    1.118 |     57.4 |
# |    3 |   2019 |    91 |     2 |    -0.346 |    24.67 |   90    | 1010.86 |    1.095 |     91.7 |
# |    4 |   2019 |    91 |     3 |    -0.471 |    24.64 |   90.6  | 1010.89 |    0.995 |     76   |
# |    5 |   2019 |    91 |     4 |    -0.444 |    24.58 |   90.6  | 1010.89 |    0.93  |     85.8 |
# |    6 |   2019 |    91 |     5 |    -0.444 |    24.59 |   90.6  | 1010.86 |    0.747 |     98.5 |
# |    7 |   2019 |    91 |     6 |    -0.431 |    24.57 |   90.4  | 1010.86 |    0.669 |     87.5 |
# |    8 |   2019 |    91 |     7 |    -0.408 |    24.6  |   90.5  | 1010.89 |    0.598 |     88.2 |
# |    9 |   2019 |    91 |     8 |    -0.448 |    24.59 |   90.7  | 1010.8  |    0.452 |     84.5 |
# |   10 |   2019 |    91 |     9 |    -0.368 |    24.58 |   90.4  | 1010.89 |    0.913 |     78.5 |

# %% [markdown]
# Below, we have the description of each of the identifiers in our dataset.
#
# |          |                |           |              |
# |----------|----------------|-----------|--------------|
# | **id:**  | A unique identifier for each record in the table.                  | **humid:** | Relative humidity. |
# | **year:**| The year to which the data refers.                                 | **press:** | Atmospheric pressure.|
# | **day:** | The day of the year when the measurements were taken.              | **tp_sfc:** | Surface temperature.|
# | **min:** | The minute of the hour when the measurements were taken.           | **ws_10m:** | Wind speed at 10 meters above the surface.|
# | **dir_avg:** | Average wind direction.                                        | **wd_10m:** | Wind direction at 10 meters above the surface.|

# %% [markdown]
# The model for predicting wind speed one hour ahead is as follows:
#
# <p style="text-align: center;">
#  <img src="../images/figure05_ann_predicted_wind_model.jpg" style="width: 700px;">
# </p>

# %% [markdown]
# Our mission is to develop artificial intelligence capable of making wind speed predictions based on the data available. The algorithm must meet the following criteria:
#
# * Implement the algorithm using TensorFlow or PyTorch,
# * Predict the wind speed two hours ahead,
# * Measure the execution time of the algorithm developed on CPU and/or GPU environment.

# %% [markdown]
# ### ☆ Solution using the CPU environment ☆

# %% [markdown]
# First we will import the libraries necessary to create our neural network, work with database, and plot graphs

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# #### **Read file with data**

# %% [markdown]
# Now we will read the data present in our .csv spreadsheet and separate the data for training.

# %%
wind_dataset = pd.read_csv("data/wind-dataset/wind-dataset.csv", sep=";", header=0)

x = wind_dataset.drop(columns=['id','year','ws_10m'])
y = wind_dataset['ws_10m']

# %%
x, y
# Out:
# (       day   min  dir_avg  tp_sfc  humid    press  wd_10m
#  0       91     0   -0.417   24.62   89.8  1010.86    64.5
#  1       91     1   -0.377   24.69   89.7  1010.83    57.4
#  2       91     2   -0.346   24.67   90.0  1010.86    91.7
#  3       91     3   -0.471   24.64   90.6  1010.89    76.0
#  4       91     4   -0.444   24.58   90.6  1010.89    85.8
#  ...    ...   ...      ...     ...    ...      ...     ...
#  43195  120  1435    0.000   21.43   81.7  1010.85    25.4
#  43196  120  1436    0.000   21.44   81.5  1010.88    16.3
#  43197  120  1437    0.000   21.44   81.9  1010.88    24.3
#  43198  120  1438    0.000   21.47   82.0  1010.85    51.4
#  43199  120  1439    0.000   21.44   81.8  1010.88    45.7
#
#  [43200 rows x 7 columns],
#  0        1.273
#  1        1.118
#  2        1.095
#  3        0.995
#  4        0.930
#           ...
#  43195    1.274
#  43196    1.563
#  43197    1.025
#  43198    0.387
#  43199    0.083
#  Name: ws_10m, Length: 43200, dtype: float64)

# %% [markdown]
# #### **Normalizing data**

# %% [markdown]
# Now it will be necessary to normalize the data so that we can train our network properly.

# %%
scaler = StandardScaler()
x = scaler.fit_transform(x)

# %% [markdown]
# #### Separate training and testing data

# %% [markdown]
# You will need to reserve part of the dataset for training and another for testing. In our case, we reserve 70% of the available data to use in our training and 30% will be used to validate our neural network.

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# #### **Show training data**

# %%
print("------------x_train data------------")
print(x_train,"\n")

print("------------y_train data------------")
print(y_train,"\n")
# Out:
# ------------x_train data------------
# [[ 0.51990416  0.03007033 -0.34625831 ... -0.01242871 -0.43006397
#   -1.1954858 ]
#  [-0.86650693 -0.31152866 -0.34637257 ... -0.61607112  0.02666017
#    0.25839491]
#  [ 1.44417822 -1.68033025 -0.34625831 ...  0.94887536 -1.47937325
#   -0.5938202 ]
#  ...
#  [ 1.32864396 -0.00360844 -0.34625831 ...  0.6237284  -0.14388872
#   -1.10012093]
#  [-1.67524673  0.33799055  2.90131922 ... -1.13489258  0.55854146
#   -1.2084901 ]
#  [-0.51990416  1.62500084 -0.34757444 ... -0.01949712  0.09025468
#   -1.23883346]]
#
# ------------y_train data------------
# 28092    1.338
# 10670    4.479
# 38901    0.426
# 23709    0.536
# 37000    3.160
#          ...
# 6265     3.404
# 11284    4.737
# 38158    1.256
# 860      3.639
# 15795    2.763
# Name: ws_10m, Length: 30240, dtype: float64

# %% [markdown]
# #### **Show data reserved for testing**

# %%
print("------------x_test data------------")
print(x_test,"\n")

print("------------y_test data------------")
print(y_test,"\n")
# Out:
# ------------x_test data------------
# [[-5.19904158e-01  9.26166280e-02  3.45824025e+00 ... -9.32735987e-01
#    8.10028809e-01 -1.04376897e+00]
#  [-2.88835643e-01 -4.69097207e-02  9.55481133e-01 ...  7.22686172e-01
#    4.92056301e-01  1.83624995e+00]
#  [-6.35438416e-01  1.26896809e+00 -3.46876169e-01 ... -6.57067908e-01
#    1.00370297e+00 -3.90953120e-01]
#  ...
#  [ 1.32864396e+00 -1.20281335e-03 -3.46258308e-01 ...  5.95454750e-01
#   -1.43888716e-01 -1.24143432e+00]
#  [-4.04369901e-01 -8.33549652e-01 -3.48683200e-01 ...  1.00542266e+00
#   -2.21936514e-01 -4.11760000e-01]
#  [ 9.82041188e-01  5.89378542e-02 -3.46258308e-01 ...  1.24574868e+00
#    1.99808973e+00  8.33184963e-01]]
#
# ------------y_test data------------
# 15158    0.456
# 17980    1.179
# 14207    0.252
# 42340    0.000
# 22155    0.000
#          ...
# 28936    0.098
# 34897    0.155
# 38159    1.994
# 16213    0.005
# 33864    1.608
# Name: ws_10m, Length: 12960, dtype: float64

# %% [markdown]
# #### **Create neural network**

# %% [markdown]
# Now that the data has been separated, let's create our neural network so that we can carry out training.

# %%
    model = tf.keras.models.Sequential()
    
    model.add(tf.keras.layers.Dense(128, input_shape=(x_train.shape[1],), activation='relu'))
    model.add(tf.keras.layers.Dense(64, activation='relu'))
    model.add(tf.keras.layers.Dense(32, activation='relu'))
    model.add(tf.keras.layers.Dense(1, activation='linear'))

# %% [markdown]
# #### **Compiling the model**

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_squared_error'])

# %% [markdown]
# #### **Training and evaluating the model**

# %%
start_training_time = time.time()

with tf.device('/CPU:0'):
        early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=200, callbacks=[early_stopping])


mse, _ = model.evaluate(x_test, y_test)
print(f'Mean Squared Error on Test Set: {mse}')

end_training_time = time.time()
# Out:
# Epoch 1/200
# 945/945 [==============================] - 3s 2ms/step - loss: 1.4623 - mean_squared_error: 1.4623 - val_loss: 0.9900 - val_mean_squared_error: 0.9900
# Epoch 2/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.8845 - mean_squared_error: 0.8845 - val_loss: 0.8141 - val_mean_squared_error: 0.8141
# Epoch 3/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.7859 - mean_squared_error: 0.7859 - val_loss: 0.8597 - val_mean_squared_error: 0.8597
# Epoch 4/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.7475 - mean_squared_error: 0.7475 - val_loss: 0.7295 - val_mean_squared_error: 0.7295
# Epoch 5/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.7104 - mean_squared_error: 0.7104 - val_loss: 0.6932 - val_mean_squared_error: 0.6932
# Epoch 6/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.6887 - mean_squared_error: 0.6887 - val_loss: 0.7534 - val_mean_squared_error: 0.7534
# Epoch 7/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.6732 - mean_squared_error: 0.6732 - val_loss: 0.6846 - val_mean_squared_error: 0.6846
# Epoch 8/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.6602 - mean_squared_error: 0.6602 - val_loss: 0.6473 - val_mean_squared_error: 0.6473
# Epoch 9/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.6483 - mean_squared_error: 0.6483 - val_loss: 0.7077 - val_mean_squared_error: 0.7077
# Epoch 10/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.6313 - mean_squared_error: 0.6313 - val_loss: 0.6381 - val_mean_squared_error: 0.6381
# Epoch 11/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.6263 - mean_squared_error: 0.6263 - val_loss: 0.6843 - val_mean_squared_error: 0.6843
# Epoch 12/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.6171 - mean_squared_error: 0.6171 - val_loss: 0.6113 - val_mean_squared_error: 0.6113
# Epoch 13/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.6123 - mean_squared_error: 0.6123 - val_loss: 0.6277 - val_mean_squared_error: 0.6277
# Epoch 14/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.6078 - mean_squared_error: 0.6078 - val_loss: 0.6025 - val_mean_squared_error: 0.6025
# Epoch 15/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.6038 - mean_squared_error: 0.6038 - val_loss: 0.6503 - val_mean_squared_error: 0.6503
# Epoch 16/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5915 - mean_squared_error: 0.5915 - val_loss: 0.5959 - val_mean_squared_error: 0.5959
# Epoch 17/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5875 - mean_squared_error: 0.5875 - val_loss: 0.5838 - val_mean_squared_error: 0.5838
# Epoch 18/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5795 - mean_squared_error: 0.5795 - val_loss: 0.5796 - val_mean_squared_error: 0.5796
# Epoch 19/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5755 - mean_squared_error: 0.5755 - val_loss: 0.5787 - val_mean_squared_error: 0.5787
# Epoch 20/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5719 - mean_squared_error: 0.5719 - val_loss: 0.5863 - val_mean_squared_error: 0.5863
# Epoch 21/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5675 - mean_squared_error: 0.5675 - val_loss: 0.5916 - val_mean_squared_error: 0.5916
# Epoch 22/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5592 - mean_squared_error: 0.5592 - val_loss: 0.5863 - val_mean_squared_error: 0.5863
# Epoch 23/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5604 - mean_squared_error: 0.5604 - val_loss: 0.5937 - val_mean_squared_error: 0.5937
# Epoch 24/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5587 - mean_squared_error: 0.5587 - val_loss: 0.5833 - val_mean_squared_error: 0.5833
# Epoch 25/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5533 - mean_squared_error: 0.5533 - val_loss: 0.5493 - val_mean_squared_error: 0.5493
# Epoch 26/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5488 - mean_squared_error: 0.5488 - val_loss: 0.5787 - val_mean_squared_error: 0.5787
# Epoch 27/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5469 - mean_squared_error: 0.5469 - val_loss: 0.5863 - val_mean_squared_error: 0.5863
# Epoch 28/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5421 - mean_squared_error: 0.5421 - val_loss: 0.5519 - val_mean_squared_error: 0.5519
# Epoch 29/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5415 - mean_squared_error: 0.5415 - val_loss: 0.5487 - val_mean_squared_error: 0.5487
# Epoch 30/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5360 - mean_squared_error: 0.5360 - val_loss: 0.5450 - val_mean_squared_error: 0.5450
# Epoch 31/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5351 - mean_squared_error: 0.5351 - val_loss: 0.5589 - val_mean_squared_error: 0.5589
# Epoch 32/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5329 - mean_squared_error: 0.5329 - val_loss: 0.5535 - val_mean_squared_error: 0.5535
# Epoch 33/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5300 - mean_squared_error: 0.5300 - val_loss: 0.5484 - val_mean_squared_error: 0.5484
# Epoch 34/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5249 - mean_squared_error: 0.5249 - val_loss: 0.5543 - val_mean_squared_error: 0.5543
# Epoch 35/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5268 - mean_squared_error: 0.5268 - val_loss: 0.5495 - val_mean_squared_error: 0.5495
# Epoch 36/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5281 - mean_squared_error: 0.5281 - val_loss: 0.5714 - val_mean_squared_error: 0.5714
# Epoch 37/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5210 - mean_squared_error: 0.5210 - val_loss: 0.5360 - val_mean_squared_error: 0.5360
# Epoch 38/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5199 - mean_squared_error: 0.5199 - val_loss: 0.5282 - val_mean_squared_error: 0.5282
# Epoch 39/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5170 - mean_squared_error: 0.5170 - val_loss: 0.5305 - val_mean_squared_error: 0.5305
# Epoch 40/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5178 - mean_squared_error: 0.5178 - val_loss: 0.5560 - val_mean_squared_error: 0.5560
# Epoch 41/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5100 - mean_squared_error: 0.5100 - val_loss: 0.5285 - val_mean_squared_error: 0.5285
# Epoch 42/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5103 - mean_squared_error: 0.5103 - val_loss: 0.5190 - val_mean_squared_error: 0.5190
# Epoch 43/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5082 - mean_squared_error: 0.5082 - val_loss: 0.5476 - val_mean_squared_error: 0.5476
# Epoch 44/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5111 - mean_squared_error: 0.5111 - val_loss: 0.5218 - val_mean_squared_error: 0.5218
# Epoch 45/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5006 - mean_squared_error: 0.5006 - val_loss: 0.5218 - val_mean_squared_error: 0.5218
# Epoch 46/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5036 - mean_squared_error: 0.5036 - val_loss: 0.5311 - val_mean_squared_error: 0.5311
# Epoch 47/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5052 - mean_squared_error: 0.5052 - val_loss: 0.5325 - val_mean_squared_error: 0.5325
# Epoch 48/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.5023 - mean_squared_error: 0.5023 - val_loss: 0.5249 - val_mean_squared_error: 0.5249
# Epoch 49/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4963 - mean_squared_error: 0.4963 - val_loss: 0.5115 - val_mean_squared_error: 0.5115
# Epoch 50/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4981 - mean_squared_error: 0.4981 - val_loss: 0.5227 - val_mean_squared_error: 0.5227
# Epoch 51/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4948 - mean_squared_error: 0.4948 - val_loss: 0.5082 - val_mean_squared_error: 0.5082
# Epoch 52/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4906 - mean_squared_error: 0.4906 - val_loss: 0.5089 - val_mean_squared_error: 0.5089
# Epoch 53/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4932 - mean_squared_error: 0.4932 - val_loss: 0.5116 - val_mean_squared_error: 0.5116
# Epoch 54/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4923 - mean_squared_error: 0.4923 - val_loss: 0.5402 - val_mean_squared_error: 0.5402
# Epoch 55/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4873 - mean_squared_error: 0.4873 - val_loss: 0.5133 - val_mean_squared_error: 0.5133
# Epoch 56/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4919 - mean_squared_error: 0.4919 - val_loss: 0.5073 - val_mean_squared_error: 0.5073
# Epoch 57/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4879 - mean_squared_error: 0.4879 - val_loss: 0.5209 - val_mean_squared_error: 0.5209
# Epoch 58/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4888 - mean_squared_error: 0.4888 - val_loss: 0.5095 - val_mean_squared_error: 0.5095
# Epoch 59/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4846 - mean_squared_error: 0.4846 - val_loss: 0.5218 - val_mean_squared_error: 0.5218
# Epoch 60/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4860 - mean_squared_error: 0.4860 - val_loss: 0.5084 - val_mean_squared_error: 0.5084
# Epoch 61/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4821 - mean_squared_error: 0.4821 - val_loss: 0.5104 - val_mean_squared_error: 0.5104
# Epoch 62/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4815 - mean_squared_error: 0.4815 - val_loss: 0.5141 - val_mean_squared_error: 0.5141
# Epoch 63/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4813 - mean_squared_error: 0.4813 - val_loss: 0.5135 - val_mean_squared_error: 0.5135
# Epoch 64/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4802 - mean_squared_error: 0.4802 - val_loss: 0.5018 - val_mean_squared_error: 0.5018
# Epoch 65/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4804 - mean_squared_error: 0.4804 - val_loss: 0.5083 - val_mean_squared_error: 0.5083
# Epoch 66/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4789 - mean_squared_error: 0.4789 - val_loss: 0.5069 - val_mean_squared_error: 0.5069
# Epoch 67/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4756 - mean_squared_error: 0.4756 - val_loss: 0.5074 - val_mean_squared_error: 0.5074
# Epoch 68/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4771 - mean_squared_error: 0.4771 - val_loss: 0.4922 - val_mean_squared_error: 0.4922
# Epoch 69/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4764 - mean_squared_error: 0.4764 - val_loss: 0.5027 - val_mean_squared_error: 0.5027
# Epoch 70/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4729 - mean_squared_error: 0.4729 - val_loss: 0.4921 - val_mean_squared_error: 0.4921
# Epoch 71/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4741 - mean_squared_error: 0.4741 - val_loss: 0.5060 - val_mean_squared_error: 0.5060
# Epoch 72/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4720 - mean_squared_error: 0.4720 - val_loss: 0.4963 - val_mean_squared_error: 0.4963
# Epoch 73/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4724 - mean_squared_error: 0.4724 - val_loss: 0.5304 - val_mean_squared_error: 0.5304
# Epoch 74/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4719 - mean_squared_error: 0.4719 - val_loss: 0.5033 - val_mean_squared_error: 0.5033
# Epoch 75/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4691 - mean_squared_error: 0.4691 - val_loss: 0.5050 - val_mean_squared_error: 0.5050
# Epoch 76/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4689 - mean_squared_error: 0.4689 - val_loss: 0.5023 - val_mean_squared_error: 0.5023
# Epoch 77/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4676 - mean_squared_error: 0.4676 - val_loss: 0.4819 - val_mean_squared_error: 0.4819
# Epoch 78/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4677 - mean_squared_error: 0.4677 - val_loss: 0.5024 - val_mean_squared_error: 0.5024
# Epoch 79/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4667 - mean_squared_error: 0.4667 - val_loss: 0.4985 - val_mean_squared_error: 0.4985
# Epoch 80/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4650 - mean_squared_error: 0.4650 - val_loss: 0.4929 - val_mean_squared_error: 0.4929
# Epoch 81/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4641 - mean_squared_error: 0.4641 - val_loss: 0.5007 - val_mean_squared_error: 0.5007
# Epoch 82/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4621 - mean_squared_error: 0.4621 - val_loss: 0.5156 - val_mean_squared_error: 0.5156
# Epoch 83/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4620 - mean_squared_error: 0.4620 - val_loss: 0.4867 - val_mean_squared_error: 0.4867
# Epoch 84/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4626 - mean_squared_error: 0.4626 - val_loss: 0.4864 - val_mean_squared_error: 0.4864
# Epoch 85/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4595 - mean_squared_error: 0.4595 - val_loss: 0.4855 - val_mean_squared_error: 0.4855
# Epoch 86/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4621 - mean_squared_error: 0.4621 - val_loss: 0.4953 - val_mean_squared_error: 0.4953
# Epoch 87/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.4580 - mean_squared_error: 0.4580 - val_loss: 0.5159 - val_mean_squared_error: 0.5159
# 405/405 [==============================] - 0s 1ms/step - loss: 0.4819 - mean_squared_error: 0.4819
# Mean Squared Error on Test Set: 0.48190024495124817

# %% [markdown]
# #### Plot learning graph

# %% [markdown]
# Let's plot a graph where we plot the training and validation curves so that we can evaluate our model.

# %%
def plot_learning_curve(history):
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.title('Learning Curve')
    plt.show()

plot_learning_curve(history)

# %% [markdown]
# ### Predicting wind speed two hours ahead

# %% [markdown]
# At this point we already have our network trained with the saved weather forecast values. Now we need to obtain the values of the predicted speed of time, move two hours forward in time, and then retrain our network so that we can obtain the future forecast.

# %% [markdown]
# Adding the <b>ws_10m_predict</b> wind forecast values that we got in our training and also adding <b>60 min</b> to our dataset and repeating this process twice to allow us to predict the wind two hours in advance.

# %%
time_to_predicted = 2 # predict the wind speed two hours ahead

# %% [markdown]
# ### Training the network with the new data

# %%
start_predicted_time = time.time()

wind_dataset_predict = wind_dataset.copy()

for _ in range (time_to_predicted):

    wind_dataset_predict['ws_10m_predict'] = model.predict(x)                            # add wind speed predictions in the table
    wind_dataset_predict['min'] = wind_dataset_predict['min'] + 60                       # add 60 min (1 hour) at min table  
    wind_dataset_predict.to_csv("data/wind-dataset/wind-dataset-predict.csv", sep=";")

    x_train, x_test, y_train, y_test = train_test_split(x, wind_dataset_predict['ws_10m_predict'], test_size=0.3, random_state=42)
    
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(128, input_shape=(x_train.shape[1],), activation='relu'))
    model.add(tf.keras.layers.Dense(64, activation='relu'))
    model.add(tf.keras.layers.Dense(32, activation='relu'))
    model.add(tf.keras.layers.Dense(1, activation='linear'))
    
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_squared_error'])
    
    with tf.device('/CPU:0'):
        early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=200, callbacks=[early_stopping])

    wind_dataset_predict['ws_10m_predict'] = model.predict(x)

plt.figure(figsize=(10, 6))
plt.plot(wind_dataset_predict['ws_10m'], label='Real wind speed')
plt.plot(wind_dataset_predict['ws_10m_predict'], label='Predicted wind speed')
plt.xlabel('Samples')
plt.ylabel('Wind speed')
plt.legend()
plt.title('Wind speed forecast')
plt.show()

end_predicted_time = time.time()
# Out:
# 1350/1350 [==============================] - 1s 1ms/step
# Epoch 1/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.8594 - mean_squared_error: 0.8594 - val_loss: 0.3851 - val_mean_squared_error: 0.3851
# Epoch 2/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.3196 - mean_squared_error: 0.3196 - val_loss: 0.2664 - val_mean_squared_error: 0.2664
# Epoch 3/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.2378 - mean_squared_error: 0.2378 - val_loss: 0.1880 - val_mean_squared_error: 0.1880
# Epoch 4/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.1981 - mean_squared_error: 0.1981 - val_loss: 0.1452 - val_mean_squared_error: 0.1452
# Epoch 5/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.1550 - mean_squared_error: 0.1550 - val_loss: 0.1229 - val_mean_squared_error: 0.1229
# Epoch 6/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.1223 - mean_squared_error: 0.1223 - val_loss: 0.1012 - val_mean_squared_error: 0.1012
# Epoch 7/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.1141 - mean_squared_error: 0.1141 - val_loss: 0.1034 - val_mean_squared_error: 0.1034
# Epoch 8/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.1004 - mean_squared_error: 0.1004 - val_loss: 0.0763 - val_mean_squared_error: 0.0763
# Epoch 9/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0893 - mean_squared_error: 0.0893 - val_loss: 0.0823 - val_mean_squared_error: 0.0823
# Epoch 10/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0860 - mean_squared_error: 0.0860 - val_loss: 0.0803 - val_mean_squared_error: 0.0803
# Epoch 11/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0797 - mean_squared_error: 0.0797 - val_loss: 0.0684 - val_mean_squared_error: 0.0684
# Epoch 12/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0747 - mean_squared_error: 0.0747 - val_loss: 0.0715 - val_mean_squared_error: 0.0715
# Epoch 13/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0710 - mean_squared_error: 0.0710 - val_loss: 0.1337 - val_mean_squared_error: 0.1337
# Epoch 14/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0681 - mean_squared_error: 0.0681 - val_loss: 0.0700 - val_mean_squared_error: 0.0700
# Epoch 15/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0610 - mean_squared_error: 0.0610 - val_loss: 0.0680 - val_mean_squared_error: 0.0680
# Epoch 16/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0608 - mean_squared_error: 0.0608 - val_loss: 0.0617 - val_mean_squared_error: 0.0617
# Epoch 17/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0569 - mean_squared_error: 0.0569 - val_loss: 0.0481 - val_mean_squared_error: 0.0481
# Epoch 18/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0584 - mean_squared_error: 0.0584 - val_loss: 0.0523 - val_mean_squared_error: 0.0523
# Epoch 19/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0540 - mean_squared_error: 0.0540 - val_loss: 0.0535 - val_mean_squared_error: 0.0535
# Epoch 20/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0509 - mean_squared_error: 0.0509 - val_loss: 0.0576 - val_mean_squared_error: 0.0576
# Epoch 21/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0521 - mean_squared_error: 0.0521 - val_loss: 0.0502 - val_mean_squared_error: 0.0502
# Epoch 22/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0489 - mean_squared_error: 0.0489 - val_loss: 0.0518 - val_mean_squared_error: 0.0518
# Epoch 23/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0499 - mean_squared_error: 0.0499 - val_loss: 0.0385 - val_mean_squared_error: 0.0385
# Epoch 24/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0445 - mean_squared_error: 0.0445 - val_loss: 0.0497 - val_mean_squared_error: 0.0497
# Epoch 25/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0451 - mean_squared_error: 0.0451 - val_loss: 0.0412 - val_mean_squared_error: 0.0412
# Epoch 26/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0418 - mean_squared_error: 0.0418 - val_loss: 0.0508 - val_mean_squared_error: 0.0508
# Epoch 27/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0459 - val_mean_squared_error: 0.0459
# Epoch 28/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0427 - mean_squared_error: 0.0427 - val_loss: 0.0370 - val_mean_squared_error: 0.0370
# Epoch 29/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0409 - mean_squared_error: 0.0409 - val_loss: 0.0382 - val_mean_squared_error: 0.0382
# Epoch 30/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0399 - mean_squared_error: 0.0399 - val_loss: 0.0348 - val_mean_squared_error: 0.0348
# Epoch 31/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0376 - mean_squared_error: 0.0376 - val_loss: 0.0326 - val_mean_squared_error: 0.0326
# Epoch 32/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0371 - mean_squared_error: 0.0371 - val_loss: 0.0351 - val_mean_squared_error: 0.0351
# Epoch 33/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0345 - mean_squared_error: 0.0345 - val_loss: 0.0309 - val_mean_squared_error: 0.0309
# Epoch 34/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0302 - val_mean_squared_error: 0.0302
# Epoch 35/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0369 - mean_squared_error: 0.0369 - val_loss: 0.0410 - val_mean_squared_error: 0.0410
# Epoch 36/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0327 - mean_squared_error: 0.0327 - val_loss: 0.0364 - val_mean_squared_error: 0.0364
# Epoch 37/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0326 - mean_squared_error: 0.0326 - val_loss: 0.0352 - val_mean_squared_error: 0.0352
# Epoch 38/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0322 - mean_squared_error: 0.0322 - val_loss: 0.0285 - val_mean_squared_error: 0.0285
# Epoch 39/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0333 - mean_squared_error: 0.0333 - val_loss: 0.0345 - val_mean_squared_error: 0.0345
# Epoch 40/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0313 - mean_squared_error: 0.0313 - val_loss: 0.0414 - val_mean_squared_error: 0.0414
# Epoch 41/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0327 - mean_squared_error: 0.0327 - val_loss: 0.0275 - val_mean_squared_error: 0.0275
# Epoch 42/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0293 - mean_squared_error: 0.0293 - val_loss: 0.0275 - val_mean_squared_error: 0.0275
# Epoch 43/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0314 - mean_squared_error: 0.0314 - val_loss: 0.0275 - val_mean_squared_error: 0.0275
# Epoch 44/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0299 - mean_squared_error: 0.0299 - val_loss: 0.0350 - val_mean_squared_error: 0.0350
# Epoch 45/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0288 - mean_squared_error: 0.0288 - val_loss: 0.0414 - val_mean_squared_error: 0.0414
# Epoch 46/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0303 - mean_squared_error: 0.0303 - val_loss: 0.0237 - val_mean_squared_error: 0.0237
# Epoch 47/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0267 - mean_squared_error: 0.0267 - val_loss: 0.0324 - val_mean_squared_error: 0.0324
# Epoch 48/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0269 - val_mean_squared_error: 0.0269
# Epoch 49/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0283 - val_mean_squared_error: 0.0283
# Epoch 50/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0272 - mean_squared_error: 0.0272 - val_loss: 0.0241 - val_mean_squared_error: 0.0241
# Epoch 51/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0259 - mean_squared_error: 0.0259 - val_loss: 0.0288 - val_mean_squared_error: 0.0288
# Epoch 52/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0267 - mean_squared_error: 0.0267 - val_loss: 0.0234 - val_mean_squared_error: 0.0234
# Epoch 53/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0255 - mean_squared_error: 0.0255 - val_loss: 0.0252 - val_mean_squared_error: 0.0252
# Epoch 54/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0253 - mean_squared_error: 0.0253 - val_loss: 0.0264 - val_mean_squared_error: 0.0264
# Epoch 55/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0251 - mean_squared_error: 0.0251 - val_loss: 0.0238 - val_mean_squared_error: 0.0238
# Epoch 56/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0254 - mean_squared_error: 0.0254 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# Epoch 57/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0244 - mean_squared_error: 0.0244 - val_loss: 0.0271 - val_mean_squared_error: 0.0271
# Epoch 58/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0242 - mean_squared_error: 0.0242 - val_loss: 0.0266 - val_mean_squared_error: 0.0266
# Epoch 59/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0244 - mean_squared_error: 0.0244 - val_loss: 0.0237 - val_mean_squared_error: 0.0237
# Epoch 60/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0244 - val_mean_squared_error: 0.0244
# Epoch 61/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0245 - mean_squared_error: 0.0245 - val_loss: 0.0267 - val_mean_squared_error: 0.0267
# Epoch 62/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 0.0284 - val_mean_squared_error: 0.0284
# 1350/1350 [==============================] - 1s 976us/step
# 1350/1350 [==============================] - 1s 959us/step
# Epoch 1/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.8167 - mean_squared_error: 0.8167 - val_loss: 0.3307 - val_mean_squared_error: 0.3307
# Epoch 2/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.2496 - mean_squared_error: 0.2496 - val_loss: 0.1714 - val_mean_squared_error: 0.1714
# Epoch 3/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.1702 - mean_squared_error: 0.1702 - val_loss: 0.1316 - val_mean_squared_error: 0.1316
# Epoch 4/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.1199 - mean_squared_error: 0.1199 - val_loss: 0.1031 - val_mean_squared_error: 0.1031
# Epoch 5/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0973 - mean_squared_error: 0.0973 - val_loss: 0.0989 - val_mean_squared_error: 0.0989
# Epoch 6/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0836 - mean_squared_error: 0.0836 - val_loss: 0.0741 - val_mean_squared_error: 0.0741
# Epoch 7/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0692 - mean_squared_error: 0.0692 - val_loss: 0.0583 - val_mean_squared_error: 0.0583
# Epoch 8/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0669 - mean_squared_error: 0.0669 - val_loss: 0.0549 - val_mean_squared_error: 0.0549
# Epoch 9/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0583 - mean_squared_error: 0.0583 - val_loss: 0.0530 - val_mean_squared_error: 0.0530
# Epoch 10/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0532 - mean_squared_error: 0.0532 - val_loss: 0.0499 - val_mean_squared_error: 0.0499
# Epoch 11/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0505 - mean_squared_error: 0.0505 - val_loss: 0.0592 - val_mean_squared_error: 0.0592
# Epoch 12/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0460 - mean_squared_error: 0.0460 - val_loss: 0.0429 - val_mean_squared_error: 0.0429
# Epoch 13/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0440 - mean_squared_error: 0.0440 - val_loss: 0.0363 - val_mean_squared_error: 0.0363
# Epoch 14/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0412 - mean_squared_error: 0.0412 - val_loss: 0.0368 - val_mean_squared_error: 0.0368
# Epoch 15/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0366 - mean_squared_error: 0.0366 - val_loss: 0.0334 - val_mean_squared_error: 0.0334
# Epoch 16/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0387 - mean_squared_error: 0.0387 - val_loss: 0.0320 - val_mean_squared_error: 0.0320
# Epoch 17/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0378 - mean_squared_error: 0.0378 - val_loss: 0.0255 - val_mean_squared_error: 0.0255
# Epoch 18/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0331 - mean_squared_error: 0.0331 - val_loss: 0.0311 - val_mean_squared_error: 0.0311
# Epoch 19/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0299 - mean_squared_error: 0.0299 - val_loss: 0.0411 - val_mean_squared_error: 0.0411
# Epoch 20/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0296 - mean_squared_error: 0.0296 - val_loss: 0.0287 - val_mean_squared_error: 0.0287
# Epoch 21/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0340 - mean_squared_error: 0.0340 - val_loss: 0.0290 - val_mean_squared_error: 0.0290
# Epoch 22/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0275 - mean_squared_error: 0.0275 - val_loss: 0.0248 - val_mean_squared_error: 0.0248
# Epoch 23/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0263 - mean_squared_error: 0.0263 - val_loss: 0.0211 - val_mean_squared_error: 0.0211
# Epoch 24/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0275 - mean_squared_error: 0.0275 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 25/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0265 - mean_squared_error: 0.0265 - val_loss: 0.0262 - val_mean_squared_error: 0.0262
# Epoch 26/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0268 - mean_squared_error: 0.0268 - val_loss: 0.0312 - val_mean_squared_error: 0.0312
# Epoch 27/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.0268 - val_mean_squared_error: 0.0268
# Epoch 28/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0272 - mean_squared_error: 0.0272 - val_loss: 0.0274 - val_mean_squared_error: 0.0274
# Epoch 29/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0266 - mean_squared_error: 0.0266 - val_loss: 0.0267 - val_mean_squared_error: 0.0267
# Epoch 30/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0236 - mean_squared_error: 0.0236 - val_loss: 0.0240 - val_mean_squared_error: 0.0240
# Epoch 31/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0284 - val_mean_squared_error: 0.0284
# Epoch 32/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0161 - val_mean_squared_error: 0.0161
# Epoch 33/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0196 - mean_squared_error: 0.0196 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 34/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.0162 - val_mean_squared_error: 0.0162
# Epoch 35/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0211 - mean_squared_error: 0.0211 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 36/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0222 - mean_squared_error: 0.0222 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 37/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0202 - mean_squared_error: 0.0202 - val_loss: 0.0224 - val_mean_squared_error: 0.0224
# Epoch 38/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0239 - val_mean_squared_error: 0.0239
# Epoch 39/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.0178 - val_mean_squared_error: 0.0178
# Epoch 40/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0205 - val_mean_squared_error: 0.0205
# Epoch 41/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 42/200
# 945/945 [==============================] - 2s 2ms/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0247 - val_mean_squared_error: 0.0247
# 1350/1350 [==============================] - 1s 957us/step

# %% [markdown]
# ### Plot wind forecast

# %% [markdown]
# Here we will plot the wind forecast for one hour ahead.

# %%
# Choose the number of samples you want to display on the chart
num_samples_to_display = 24

# Plot a graph to compare ws_10m and ws_10m_predict with the selected number of samples
plt.figure(figsize=(10, 6))
plt.plot(wind_dataset_predict['ws_10m'][:num_samples_to_display], label='Real wind speed')
plt.plot(wind_dataset_predict['ws_10m_predict'][:num_samples_to_display], label='Predicted wind speed 2 hours')
plt.xlabel('Time')
plt.ylabel('Wind speed')
plt.legend()
plt.title('Wind speed forecast')
plt.show()

# %% [markdown]
# ### Measuring the algorithm execution time

# %% [markdown]
# As part of the work, we will measure the execution time of our algorithm, which in this case was executed on a CPU.

# %%
training_time  = end_training_time  - start_training_time
predicted_time = end_predicted_time - start_predicted_time

print(f"\nCPU Training wind time: {training_time:.2f} seconds or ({training_time / 60:.2f} minutes)")
print(f"\nCPU Predicted wind time: {predicted_time:.2f} seconds or ({predicted_time / 60:.2f} minutes)")
# Out:
# CPU Training wind time: 142.45 seconds or (2.37 minutes)
#
# CPU Predicted wind time: 175.65 seconds or (2.93 minutes)
